# %%
pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.6-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.6

# %% [markdown]
# **Libraries**

# %%
from google_play_scraper import app,Sort, reviews

import pandas as pd

import numpy as np

# %%
from google_play_scraper import Sort, reviews_all


us_reviews = reviews_all(
    'com.urbanclap.urbanclap',
    sleep_milliseconds=0, # defaults to 0
    lang='en', # defaults to 'en'
    country='us', # defaults to 'us'
    sort=Sort.NEWEST, # defaults to Sort.MOST_RELEVANT
)

# %%
df_busu = pd.DataFrame(np.array(us_reviews),columns=['review'])


df_busu = df_busu.join(pd.DataFrame(df_busu.pop('review').tolist()))


df_busu.keys()
# Out:
# Index(['reviewId', 'userName', 'userImage', 'content', 'score',
#        'thumbsUpCount', 'reviewCreatedVersion', 'at', 'replyContent',
#        'repliedAt', 'appVersion'],
#       dtype='object')

# %%
df_data  = df_busu[['userName','content','at','score']]

# %%
df_data
# Out:
#                 userName                                            content  \
# 0       Maha Mahalaskhim                                             ok bro
# 1           RAJAT SHARMA                       The issue is quickly solved.
# 2         Shivangi Gupta  No customer care number, you can only talk to ...
# 3       Lakshmi Prasanna  Avoid altogether - below average service, too ...
# 4              Prit Bawa                                       good service
# ..                   ...                                                ...
# 393          Dil keshwar                                          very nice
# 394          Vivek Kumar  Wrost experience go with your nearby professio...
# 395       Malik Sadullah  Service bekar hai....uc filter machine me prbl...
# 396  Yenubothula Mounika                                          very good
# 397         Mukesh kumar                       good person sending for work
#
#                      at  score
# 0   2024-05-01 13:57:05      5
# 1   2024-05-01 13:42:35      5
# 2   2024-05-01 13:34:44      1
# 3   2024-05-01 13:33:21      1
# 4   2024-05-01 13:14:26      4
# ..                  ...    ...
# 393 2024-04-27 07:01:43      5
# 394 2024-04-27 06:56:04      1
# 395 2024-04-27 06:51:45      1
# 396 2024-04-27 06:46:42      5
# 397 2024-04-27 06:46:16      5
#
# [398 rows x 4 columns]

# %%
df_data.to_csv('UC.csv')
